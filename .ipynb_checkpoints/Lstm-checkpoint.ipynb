# %%
# 加载数据分析常用库
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
import matplotlib.pyplot as plt
import glob, os
import seaborn as sns
import sys
from sklearn.preprocessing import MinMaxScaler


#查看其中一个地区的训练数据
#feature=['YEAR','MONTH','DAY','TEMP_HIG','TEMP_COL','AVG_TEMP','AVG_WET','DATA_COL']
example = pd.read_csv('./data/dataCleaned.csv')
example.head()

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    #将数据存储成二维数据结构中
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        #将数据值都下移一个单位，用来做标题
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        #print(names)
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        #print(cols)
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
        #print(names)
    # put it all together
    agg = pd.concat(cols, axis=1)
    #print(agg)
    agg.columns = names
    #print(agg)
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
        
# 将数据归一化到0-1之间,无量纲化
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(example[['Doctor','Disease','WaitTime']].values)
#print(scaled_data[455:])
# 将时序数据转换为监督问题数据
reframed = series_to_supervised(scaled_data, 1, 1)
#print(reframed)
#删除无用的label数据，只预测TEMP_HIG
reframed.drop(reframed.columns[[3,4]], axis=1, inplace=True)
#print(reframed.values)

# 数据集划分,选取前400天的数据作为训练集,中间150天作为验证集,其余的作为测试集
train_days = 300
valid_days = 100
values = reframed.values
train = values[:train_days, :]
valid = values[train_days:train_days+valid_days, :]
test = values[train_days+valid_days:, :]
#获取训练数据集
train_X, train_y = train[:, :-1], train[:, -1]
#获取验证数据集
valid_X, valid_y = valid[:, :-1], valid[:, -1]
#获取测试数据集
test_X, test_y = test[:, :-1], test[:, -1]
# 将数据集重构为符合LSTM要求的数据格式,即 [样本，时间步，特征]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
valid_X = valid_X.reshape((valid_X.shape[0], 1, valid_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
#print(test_y.shape)

#模型构建
model = Sequential()
model.add(LSTM(50, activation='relu',input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')  #loss='mae'
model.summary() 

history = model.fit(train_X, train_y, epochs=100, batch_size=32, validation_data=(valid_X, valid_y), verbose=2, shuffle=False)


plt.figure(figsize=(24,8))
train_predict = model.predict(train_X)
valid_predict = model.predict(valid_X)
test_predict = model.predict(test_X)
#真实数据
plt.plot(values[:, -1], c='b')
#plt.plot([x for x in train_predict], c='g')
plt.plot([None for _ in train_predict] + [x for x in valid_predict], c='y')
plt.plot([None for _ in train_predict] + [None for _ in valid_predict] + [x for x in test_predict], c='r')
plt.show()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_17 (LSTM)               (None, 50)                10800
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 10,851
# Trainable params: 10,851
# Non-trainable params: 0
# _________________________________________________________________
# Train on 300 samples, validate on 100 samples
# Epoch 1/100
#  - 0s - loss: 0.1473 - val_loss: 0.1796
# Epoch 2/100
#  - 0s - loss: 0.1262 - val_loss: 0.1553
# Epoch 3/100
#  - 0s - loss: 0.1070 - val_loss: 0.1327
# Epoch 4/100
#  - 0s - loss: 0.0896 - val_loss: 0.1116
# Epoch 5/100
#  - 0s - loss: 0.0742 - val_loss: 0.0928
# Epoch 6/100
#  - 0s - loss: 0.0619 - val_loss: 0.0776
# Epoch 7/100
#  - 0s - loss: 0.0534 - val_loss: 0.0670
# Epoch 8/100
#  - 0s - loss: 0.0486 - val_loss: 0.0606
# Epoch 9/100
#  - 0s - loss: 0.0463 - val_loss: 0.0575
# Epoch 10/100
#  - 0s - loss: 0.0453 - val_loss: 0.0561
# Epoch 11/100
#  - 0s - loss: 0.0446 - val_loss: 0.0558
# Epoch 12/100
#  - 0s - loss: 0.0441 - val_loss: 0.0559
# Epoch 13/100
#  - 0s - loss: 0.0436 - val_loss: 0.0561
# Epoch 14/100
#  - 0s - loss: 0.0430 - val_loss: 0.0563
# Epoch 15/100
#  - 0s - loss: 0.0426 - val_loss: 0.0563
# Epoch 16/100
#  - 0s - loss: 0.0421 - val_loss: 0.0563
# Epoch 17/100
#  - 0s - loss: 0.0417 - val_loss: 0.0562
# Epoch 18/100
#  - 0s - loss: 0.0413 - val_loss: 0.0561
# Epoch 19/100
#  - 0s - loss: 0.0409 - val_loss: 0.0560
# Epoch 20/100
#  - 0s - loss: 0.0406 - val_loss: 0.0559
# Epoch 21/100
#  - 0s - loss: 0.0403 - val_loss: 0.0558
# Epoch 22/100
#  - 0s - loss: 0.0400 - val_loss: 0.0557
# Epoch 23/100
#  - 0s - loss: 0.0397 - val_loss: 0.0556
# Epoch 24/100
#  - 0s - loss: 0.0394 - val_loss: 0.0555
# Epoch 25/100
#  - 0s - loss: 0.0392 - val_loss: 0.0553
# Epoch 26/100
#  - 0s - loss: 0.0390 - val_loss: 0.0552
# Epoch 27/100
#  - 0s - loss: 0.0388 - val_loss: 0.0551
# Epoch 28/100
#  - 0s - loss: 0.0386 - val_loss: 0.0550
# Epoch 29/100
#  - 0s - loss: 0.0385 - val_loss: 0.0549
# Epoch 30/100
#  - 0s - loss: 0.0383 - val_loss: 0.0548
# Epoch 31/100
#  - 0s - loss: 0.0382 - val_loss: 0.0548
# Epoch 32/100
#  - 0s - loss: 0.0381 - val_loss: 0.0547
# Epoch 33/100
#  - 0s - loss: 0.0380 - val_loss: 0.0547
# Epoch 34/100
#  - 0s - loss: 0.0379 - val_loss: 0.0546
# Epoch 35/100
#  - 0s - loss: 0.0378 - val_loss: 0.0546
# Epoch 36/100
#  - 0s - loss: 0.0377 - val_loss: 0.0546
# Epoch 37/100
#  - 0s - loss: 0.0377 - val_loss: 0.0545
# Epoch 38/100
#  - 0s - loss: 0.0376 - val_loss: 0.0546
# Epoch 39/100
#  - 0s - loss: 0.0376 - val_loss: 0.0546
# Epoch 40/100
#  - 0s - loss: 0.0376 - val_loss: 0.0547
# Epoch 41/100
#  - 0s - loss: 0.0375 - val_loss: 0.0547
# Epoch 42/100
#  - 0s - loss: 0.0375 - val_loss: 0.0547
# Epoch 43/100
#  - 0s - loss: 0.0375 - val_loss: 0.0548
# Epoch 44/100
#  - 0s - loss: 0.0374 - val_loss: 0.0548
# Epoch 45/100
#  - 0s - loss: 0.0374 - val_loss: 0.0548
# Epoch 46/100
#  - 0s - loss: 0.0374 - val_loss: 0.0548
# Epoch 47/100
#  - 0s - loss: 0.0374 - val_loss: 0.0548
# Epoch 48/100
#  - 0s - loss: 0.0374 - val_loss: 0.0548
# Epoch 49/100
#  - 0s - loss: 0.0374 - val_loss: 0.0549
# Epoch 50/100
#  - 0s - loss: 0.0374 - val_loss: 0.0549
# Epoch 51/100
#  - 0s - loss: 0.0373 - val_loss: 0.0549
# Epoch 52/100
#  - 0s - loss: 0.0373 - val_loss: 0.0550
# Epoch 53/100
#  - 0s - loss: 0.0373 - val_loss: 0.0549
# Epoch 54/100
#  - 0s - loss: 0.0373 - val_loss: 0.0550
# Epoch 55/100
#  - 0s - loss: 0.0373 - val_loss: 0.0550
# Epoch 56/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 57/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 58/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 59/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 60/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 61/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 62/100
#  - 0s - loss: 0.0372 - val_loss: 0.0551
# Epoch 63/100
#  - 0s - loss: 0.0373 - val_loss: 0.0551
# Epoch 64/100
#  - 0s - loss: 0.0372 - val_loss: 0.0551
# Epoch 65/100
#  - 0s - loss: 0.0372 - val_loss: 0.0550
# Epoch 66/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 67/100
#  - 0s - loss: 0.0372 - val_loss: 0.0550
# Epoch 68/100
#  - 0s - loss: 0.0372 - val_loss: 0.0550
# Epoch 69/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 70/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 71/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 72/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 73/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 74/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 75/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 76/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 77/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 78/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 79/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 80/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 81/100
#  - 0s - loss: 0.0372 - val_loss: 0.0548
# Epoch 82/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 83/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 84/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 85/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 86/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 87/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 88/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 89/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 90/100
#  - 0s - loss: 0.0372 - val_loss: 0.0549
# Epoch 91/100
